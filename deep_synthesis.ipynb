# %% [markdown]
# # Fire Risk Modeling Exercise Review
#
# ### Overview
#
# This notebook contains the following steps:
#
# 1. Retrieve information on all workspaces in the **Fire Risk Modeling Exercise - All Submissions** project.
# 2. Download all files available for review from every workspace in the project, including those stored on Google Drive.
# 3. Preprocess the downloaded files from each workspace.
# 4. Generate a comprehensive report for each workspace.
#
# **The process may take up to 3 hours to complete.**
#
# ---
#
# ### Requirements
#
# Before running this notebook, complete the following setup steps:
#
# #### 1. Configure the `.env` File
#
# Add the following entry to the `.env` file located in the same directory as the notebook:
# ```
# NRP_API_KEY=your_key
# ```
#
# #### 2. Store the Google Drive Access Key
# Place the Google Drive access key at the following path:
# ```
# ~/work/_User-Persistent-Storage_CephBlock_/.gdrive_token.json
# ```
#
# ---
#
# ### Results
#
# All workspaces are saved under
# ```
# _deep_synthesis_sage_/Fire_Risk_Modeling_Exercise_-_Deep_Synthesis
# ```
#
# All submissions that are not in any workspaces are saved under
# ```
# _deep_synthesis_sage_/missing_rubrics
# ```
# The report of each workspace can be found in the correspondent subfolder.

# %%
# %reset

# %% [markdown]
# ### Install Required Skills

# %%
# %%skill
# private_skills/wildfire-fetch-review-data
# private_skills/wildfire-rubric-review
# private_skills/wildfire-comprehensive-report-v2

# %% [markdown]
# ## Process All Submissions That Are Not in Any Workspaces

# %% [markdown]
# #### Download data (submissions + evaluator feedback files)

# %%
# %%ask
# Download the wildfire review data bundle for the Fire Risk Modeling Exercise:
# the submissions that have no NDP workspaces, and the two evaluator-feedback
# Excel files.

# %% [markdown]
# #### Generate rubric reviews for the 12 missing-workspace submissions

# %%
# %%ask
# Generate both rubric reviews for the submissions at
# missing_rubrics/Deep_Synthesis__FlameMapper_(Forest)
# missing_rubrics/Deep_Synthesis__FlameMapper_(Prairie)
# missing_rubrics/Deep_Synthesis__PinePeak_(Forest)
# missing_rubrics/Deep_Synthesis__PinePeak_(Prairie)
# missing_rubrics/Deep_Synthesis__TenaxAI_(Forest)
# missing_rubrics/Deep_Synthesis__TenaxAI_(Prairie)
# missing_rubrics/Deep_Synthesis__Vanderbilt_WUI_AGNI_NAR_(Forest)
# missing_rubrics/Deep_Synthesis__Vanderbilt_WUI_AGNI_NAR_(Prairie)
# missing_rubrics/Deep_Synthesis__Vanderbilt_WUI_ANN_(Forest)
# missing_rubrics/Deep_Synthesis__Vanderbilt_WUI_ANN_(Prairie)
# missing_rubrics/Deep_Synthesis__Zesty_AI_(Forest)
# missing_rubrics/Deep_Synthesis__Zesty_AI_(Prairie)

# %% [markdown]
# #### Generate comprehensive reports for the 12 missing-workspace submissions

# %%
# %%ask
# Generate comprehensive reports for the following submissions at
# missing_rubrics/Deep_Synthesis__FlameMapper_(Forest)
# missing_rubrics/Deep_Synthesis__FlameMapper_(Prairie)
# missing_rubrics/Deep_Synthesis__PinePeak_(Forest)
# missing_rubrics/Deep_Synthesis__PinePeak_(Prairie)
# missing_rubrics/Deep_Synthesis__TenaxAI_(Forest)
# missing_rubrics/Deep_Synthesis__TenaxAI_(Prairie)
# missing_rubrics/Deep_Synthesis__Vanderbilt_WUI_AGNI_NAR_(Forest)
# missing_rubrics/Deep_Synthesis__Vanderbilt_WUI_AGNI_NAR_(Prairie)
# missing_rubrics/Deep_Synthesis__Vanderbilt_WUI_ANN_(Forest)
# missing_rubrics/Deep_Synthesis__Vanderbilt_WUI_ANN_(Prairie)
# missing_rubrics/Deep_Synthesis__Zesty_AI_(Forest)
# missing_rubrics/Deep_Synthesis__Zesty_AI_(Prairie)

# %% [markdown]
# ### Retrieve Information of All Workspaces in The Project

# %%
# %%ask
# The NDP project "Fire Risk Modeling Exercise - All Submissions" lives
# in the context WSTC. Please summarize the workspaces in this project.

# %% [markdown]
# ### Download Files for The Workspaces in The Project

# %%
# %%ask
# Download all workspaces in this project.
# Skip .tif, .tfw, .ovr, .tpkx, .lyrx, .gdb, .mxd, and .png files.

# %% [markdown]
# ### Preprocess First 7 Forest Submissions
#
# Preprocessing is required to generate a comprehensive report and
# may take 5-8 minutes to complete for a submission.

# %%
# %%ask
# Generate rubric reviews for the following workspaces:
# Deep_Synthesis__ELMFIRE_(Forest)
# Deep_Synthesis__FiSci_(Forest)
# Deep_Synthesis__Firesafe_(Forest)
# Deep_Synthesis__French_National_Center_for_Scientific_Research_team_(Forest)
# Deep_Synthesis__IMAGECAT_(Forest)
# Deep_Synthesis__Minerva_University_(Forest)
# Deep_Synthesis__OroraTech_(Forest)

# %% [markdown]
# ### Preprocess the Next 7 Forest Submissions

# %%
# %%ask
# Generate rubric reviews for the following workspaces:
# Deep_Synthesis__Pyrologix_and_Vibrant_Planet_(Forest)
# Deep_Synthesis__SIG_(Forest)
# Deep_Synthesis__San_Jose_State_(Forest)
# Deep_Synthesis__SkyTL_(Forest)
# Deep_Synthesis__UCI_CHRS_(Forest)
# Deep_Synthesis__UNR_(Forest)
# Deep_Synthesis__XyloPlan_(Forest)

# %% [markdown]
# ### Generate Comprehensive Review Report for 14 Forest Submissions

# %%
# %%ask
# Generate a comprehensive report for each of the following workspaces:
# Deep_Synthesis__ELMFIRE_(Forest)
# Deep_Synthesis__FiSci_(Forest)
# Deep_Synthesis__Firesafe_(Forest)
# Deep_Synthesis__French_National_Center_for_Scientific_Research_team_(Forest)
# Deep_Synthesis__IMAGECAT_(Forest)
# Deep_Synthesis__Minerva_University_(Forest)
# Deep_Synthesis__OroraTech_(Forest)
# Deep_Synthesis__Pyrologix_and_Vibrant_Planet_(Forest)
# Deep_Synthesis__SIG_(Forest)
# Deep_Synthesis__San_Jose_State_(Forest)
# Deep_Synthesis__SkyTL_(Forest)
# Deep_Synthesis__UCI_CHRS_(Forest)
# Deep_Synthesis__UNR_(Forest)
# Deep_Synthesis__XyloPlan_(Forest)

# %% [markdown]
# ### Preprocess the First 7 Prairie Submissions

# %%
# %%ask
# Generate rubric reviews for the following workspaces:
# Deep_Synthesis__ELMFIRE_(Prairie)
# Deep_Synthesis__FiSci_(Prairie)
# Deep_Synthesis__Firesafe_(Prairie)
# Deep_Synthesis__French_National_Center_for_Scientific_Research_team_(Prairie)
# Deep_Synthesis__IMAGECAT_(Prairie)
# Deep_Synthesis__Minerva_University_(Prairie)
# Deep_Synthesis__OroraTech_(Prairie)

# %% [markdown]
# ### Preprocess the Next 7 Prairie Submissions

# %%
# %%ask
# Generate rubric reviews for the following workspaces:
# Deep_Synthesis__Pyrologix_and_Vibrant_Planet_(Prairie)
# Deep_Synthesis__SIG_(Prairie)
# Deep_Synthesis__San_Jose_State_(Prairie)
# Deep_Synthesis__SkyTL_(Prairie)
# Deep_Synthesis__UCI_CHRS_(Prairie)
# Deep_Synthesis__UNR_(Prairie)
# Deep_Synthesis__XyloPlan_(Prairie)

# %% [markdown]
# ### Generate Comprehensive Review Report for 14 Prairie Submissions

# %%
# %%ask
# Generate a comprehensive report for the following workspaces:
# Deep_Synthesis__ELMFIRE_(Prairie)
# Deep_Synthesis__FiSci_(Prairie)
# Deep_Synthesis__Firesafe_(Prairie)
# Deep_Synthesis__French_National_Center_for_Scientific_Research_team_(Prairie)
# Deep_Synthesis__IMAGECAT_(Prairie)
# Deep_Synthesis__Minerva_University_(Prairie)
# Deep_Synthesis__OroraTech_(Prairie)
# Deep_Synthesis__Pyrologix_and_Vibrant_Planet_(Prairie)
# Deep_Synthesis__SIG_(Prairie)
# Deep_Synthesis__San_Jose_State_(Prairie)
# Deep_Synthesis__SkyTL_(Prairie)
# Deep_Synthesis__UCI_CHRS_(Prairie)
# Deep_Synthesis__UNR_(Prairie)
# Deep_Synthesis__XyloPlan_(Prairie)
